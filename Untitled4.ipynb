# %% [markdown]
# <a href="https://colab.research.google.com/github/kmujk25/Python_Basic/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[1,2,3,4]

# %%
type(a)
# Out:
# list
